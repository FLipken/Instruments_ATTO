# %% [markdown]
# # Introduction to Cloud Radar 'Mira-35c'
# by Friederike Lipken (lipken@usp.br) 03/2025

# %% [markdown]
# ## 1. Import packages, load data, and define variables

# %%
#import packages
import os
import netCDF4 as nc
import xarray as xr
import numpy as np
import matplotlib.pyplot as plt
import tarfile
import matplotlib.dates as mdates
import datetime as dt

# %%
ds1=nc.Dataset('/media/flipken/Elements/PhD_ATTO/Cloud_data/Mira-35c/2020/10/13/20201013_0000.nc')
ds2=nc.Dataset('/media/flipken/Elements/PhD_ATTO/Cloud_data/Mira-35c/2020/10/13/20201013_0100.nc')
ds3=nc.Dataset('/media/flipken/Elements/PhD_ATTO/Cloud_data/Mira-35c/2020/10/13/20201013_0200.nc')
ds4=nc.Dataset('/media/flipken/Elements/PhD_ATTO/Cloud_data/Mira-35c/2020/10/13/20201013_0300.nc')
ds5=nc.Dataset('/media/flipken/Elements/PhD_ATTO/Cloud_data/Mira-35c/2020/10/13/20201013_0400.nc')
ds6=nc.Dataset('/media/flipken/Elements/PhD_ATTO/Cloud_data/Mira-35c/2020/10/13/20201013_0500.nc')
ds7=nc.Dataset('/media/flipken/Elements/PhD_ATTO/Cloud_data/Mira-35c/2020/10/13/20201013_0600.nc')
ds8=nc.Dataset('/media/flipken/Elements/PhD_ATTO/Cloud_data/Mira-35c/2020/10/13/20201013_0700.nc')
ds9=nc.Dataset('/media/flipken/Elements/PhD_ATTO/Cloud_data/Mira-35c/2020/10/13/20201013_0800.nc')
ds10=nc.Dataset('/media/flipken/Elements/PhD_ATTO/Cloud_data/Mira-35c/2020/10/13/20201013_0900.nc')
ds11=nc.Dataset('/media/flipken/Elements/PhD_ATTO/Cloud_data/Mira-35c/2020/10/13/20201013_1000.nc')
ds12=nc.Dataset('/media/flipken/Elements/PhD_ATTO/Cloud_data/Mira-35c/2020/10/13/20201013_1100.nc')
ds13=nc.Dataset('/media/flipken/Elements/PhD_ATTO/Cloud_data/Mira-35c/2020/10/13/20201013_1200.nc')
ds14=nc.Dataset('/media/flipken/Elements/PhD_ATTO/Cloud_data/Mira-35c/2020/10/13/20201013_1300.nc')
ds15=nc.Dataset('/media/flipken/Elements/PhD_ATTO/Cloud_data/Mira-35c/2020/10/13/20201013_1400.nc')
ds16=nc.Dataset('/media/flipken/Elements/PhD_ATTO/Cloud_data/Mira-35c/2020/10/13/20201013_1500.nc')
ds17=nc.Dataset('/media/flipken/Elements/PhD_ATTO/Cloud_data/Mira-35c/2020/10/13/20201013_1600.nc')
ds18=nc.Dataset('/media/flipken/Elements/PhD_ATTO/Cloud_data/Mira-35c/2020/10/13/20201013_1700.nc')
ds19=nc.Dataset('/media/flipken/Elements/PhD_ATTO/Cloud_data/Mira-35c/2020/10/13/20201013_1800.nc')
ds20=nc.Dataset('/media/flipken/Elements/PhD_ATTO/Cloud_data/Mira-35c/2020/10/13/20201013_1900.nc')
ds21=nc.Dataset('/media/flipken/Elements/PhD_ATTO/Cloud_data/Mira-35c/2020/10/13/20201013_2000.nc')
ds22=nc.Dataset('/media/flipken/Elements/PhD_ATTO/Cloud_data/Mira-35c/2020/10/13/20201013_2100.nc')
ds23=nc.Dataset('/media/flipken/Elements/PhD_ATTO/Cloud_data/Mira-35c/2020/10/13/20201013_2200.nc')
ds24=nc.Dataset('/media/flipken/Elements/PhD_ATTO/Cloud_data/Mira-35c/2020/10/13/20201013_2300.nc')

# %%
print(ds1.variables)
# Out:
# {'filtered_reflectivity': <class 'netCDF4._netCDF4.Variable'>
# float32 filtered_reflectivity(range, time)
#     _FillValue: nan
#     long_name: Filtered Equivalent Reflectivity Factor
#     units: dBZ
#     valid_range: [-60.  30.]
#     standard_name: Ze
# unlimited dimensions: time
# current shape = (573, 703)
# filling on, 'filtered_velocity': <class 'netCDF4._netCDF4.Variable'>
# float32 filtered_velocity(range, time)
#     _FillValue: nan
#     long_name: Filtered Mean Doppler Velocity
#     units: m * s^-1
#     valid_range: [-10.676638  10.676638]
#     standard_name: VEL
# unlimited dimensions: time
# current shape = (573, 703)
# filling on, 'filtered_linear_depolarization_ratio': <class 'netCDF4._netCDF4.Variable'>
# float32 filtered_linear_depolarization_ratio(range, time)
#     _FillValue: nan
#     long_name: Filtered Linear De-Polarization Ratio
#     units: dB
#     valid_range: [-35.   5.]
#     standard_name: LDR
# unlimited dimensions: time
# ...

# %%
# print global attributes 
for attr in ds1.ncattrs():
    print(f"{attr}: {getattr(ds1, attr)}")
# Out:
# convention: CF-1.0
# location: ATTO Campina
# system: C5XC
# title: MIRA Cloud Radar Data
# institution: USP
# source: 201013_000004.pds.off
# reference: Ka Band Cloud Radar MIRA, METEK GmbH www.metek.de
# Copywright:
# Copywright_Owner:
# notes: It is accounted for the Receiver Bwd Loss in Radarconst*, and Z*.

# %% [markdown]
# ## 2. Plot data

# %% [markdown]
# ### define variables

# %%
# Define Reflectivity
Ze1 = ds1.variables['filtered_reflectivity']
Ze2 = ds2.variables['filtered_reflectivity']
Ze3 = ds3.variables['filtered_reflectivity']
Ze4 = ds4.variables['filtered_reflectivity']
Ze5 = ds5.variables['filtered_reflectivity']
Ze6 = ds6.variables['filtered_reflectivity']
Ze7 = ds7.variables['filtered_reflectivity']
Ze8 = ds8.variables['filtered_reflectivity']
Ze9 = ds9.variables['filtered_reflectivity']
Ze10 = ds10.variables['filtered_reflectivity']
Ze11 = ds11.variables['filtered_reflectivity']
Ze12 = ds12.variables['filtered_reflectivity']
Ze13 = ds13.variables['filtered_reflectivity']
Ze14 = ds14.variables['filtered_reflectivity']
Ze15 = ds15.variables['filtered_reflectivity']
Ze16 = ds16.variables['filtered_reflectivity']
Ze17 = ds17.variables['filtered_reflectivity']
Ze18 = ds18.variables['filtered_reflectivity']
Ze19 = ds19.variables['filtered_reflectivity']
Ze20 = ds20.variables['filtered_reflectivity']
Ze21 = ds21.variables['filtered_reflectivity']
Ze22 = ds22.variables['filtered_reflectivity']
Ze23 = ds23.variables['filtered_reflectivity']
Ze24 = ds24.variables['filtered_reflectivity']

# Define Time
time1 = ds1.variables['time']
time2 = ds2.variables['time']
time3 = ds3.variables['time']
time4 = ds4.variables['time']
time5 = ds5.variables['time']
time6 = ds6.variables['time']
time7 = ds7.variables['time']
time8 = ds8.variables['time']
time9 = ds9.variables['time']
time10 = ds10.variables['time']
time11 = ds11.variables['time']
time12 = ds12.variables['time']
time13 = ds13.variables['time']
time14 = ds14.variables['time']
time15 = ds15.variables['time']
time16 = ds16.variables['time']
time17 = ds17.variables['time']
time18 = ds18.variables['time']
time19 = ds19.variables['time']
time20 = ds20.variables['time']
time21 = ds21.variables['time']
time22 = ds22.variables['time']
time23 = ds23.variables['time']
time24 = ds24.variables['time']

# Define height (here 'range')
range = ds1.variables['range']

# %%
# Concatenate all variables

Ze_tot= np.concatenate((Ze1, Ze2, Ze3, Ze4, Ze5, Ze6, Ze7, Ze8, Ze9, Ze10, Ze11, Ze12, Ze13, Ze14, Ze15, Ze16, Ze17, Ze18, Ze19, Ze20, Ze21, Ze22, Ze23, Ze24), axis=1)
time_tot= np.concatenate((time1, time2, time3, time4, time5, time6, time7, time8, time9, time10, time11, time12, time13, time14, time15, time16, time17, time18, time19, time20, time21, time22, time23, time24), axis=0)

# Convert 'range' to a np array
range_array = np.array(range)

# %%
#Convert UNIX epoch time to datetime
time_tot = np.array(time_tot)  # make  sure it's a np array
time_tot_dt = [mdates.date2num(dt.datetime.utcfromtimestamp(t)) for t in time_tot]

# %%
#Plot Reflectivity
fig, ax = plt.subplots(figsize=(20, 10))

# Define aspect ratio
aspectr = 0.5 * ((time_tot_dt[-1] - time_tot_dt[0]) / (range[-1] - range[0]))
plt.imshow(Ze_tot[:,:], extent=[time_tot_dt[0], time_tot_dt[-1], range[0], range[-1]], cmap='turbo', origin='lower', aspect=aspectr)
#cmap='pyart_Carbone17'
plt.xlabel('Time (UTC)', fontsize=15)
plt.ylabel('Height (m, AGL)', fontsize=15)

# Add colorbar
#cbar = plt.colorbar()
cbar = plt.colorbar(pad=0.02, fraction=0.02)
cbar.set_label(label='Ze (dBz)', size=10)

# Colorbar tick labels a bit bigger
cbar.ax.tick_params(labelsize=12, length=2, width=1.1, pad=1)
plt.clim(-50, 30)

ax = plt.gca()
ax.xaxis_date()



# Add title
plt.title("Equivalent Reflectivity 2020-10-20", fontsize=18)

plt.show()
